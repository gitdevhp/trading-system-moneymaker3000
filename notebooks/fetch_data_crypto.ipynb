# %%
import sys
from pathlib import Path

# Add parent directory to path so we can import pipeline
sys.path.insert(0, str(Path.cwd().parent))

# %% [markdown]
# Fetch crypto data from Alpaca

# %%
from pipeline.alpaca import fetch_crypto_bars, save_bars, clean_market_data

symbol = 'BTC/USD'
timeframe = '1Min'
limit = 1000

raw_df = fetch_crypto_bars(symbol, timeframe=timeframe, limit=limit)
raw_path = save_bars(raw_df, symbol, timeframe, asset_class='crypto')
clean_path = clean_market_data(raw_path)

print('Raw:', raw_path)
print('Clean:', clean_path)
print('bye')
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[3], line 7
#       4 timeframe = '1Min'
#       5 limit = 1000
# ----> 7 raw_df = fetch_crypto_bars(symbol, timeframe=timeframe, limit=limit)
#       8 raw_path = save_bars(raw_df, symbol, timeframe, asset_class='crypto')
#       9 clean_path = clean_market_data(raw_path)
#
# File c:\Users\jaden\trading-system-moneymaker3000\pipeline\alpaca.py:168, in fetch_crypto_bars(symbol, timeframe, limit, fallback_days, api)
#     166 tf = _parse_timeframe(timeframe)
#     167 if hasattr(api, "get_crypto_bars"):
# --> 168     bars = api.get_crypto_bars(symbol, tf, limit=limit).df
#     169 else:
#     170     raise RuntimeError("alpaca_trade_api does not support get_crypto_bars in this version.")
#
# ...
