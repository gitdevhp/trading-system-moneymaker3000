# %%
import sys
from pathlib import Path

# Add parent directory to path so we can import pipeline
sys.path.insert(0, str(Path.cwd().parent))

# %% [markdown]
# Fetch stock data from Alpaca

# %%
from pipeline.alpaca import fetch_stock_bars, save_bars, clean_market_data

symbol = 'AAPL'
timeframe = '1Min'
limit = 1000

raw_df = fetch_stock_bars(symbol, timeframe=timeframe, limit=limit)
raw_path = save_bars(raw_df, symbol, timeframe, asset_class='stock')
clean_path = clean_market_data(raw_path)

print('Raw:', raw_path)
print('Clean:', clean_path)
# Out:
# Raw: data\AAPL_1Min_stock_alpaca_raw.csv
# Clean: data\AAPL_1Min_stock_alpaca_clean.csv
# c:\Users\jaden\trading-system-moneymaker3000\pipeline\alpaca.py:220: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["rolling_volume"] = df["Volume"].rolling(60).mean().fillna(method="bfill")
